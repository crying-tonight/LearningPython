# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Elliot\Documents\GitHub\LearningPython\Finance\Stocks\portfolio1.csv', encoding='utf8')
df.head()
# Out:
#   Symbol  Quantity  Purchase Price  Current Price      Cost    Change   Open  \
# 0      O       3.0         58.8900          55.26  176.6700  0.349998  55.40
# 1      O      13.0         55.4800          55.26  721.2400  0.349998  55.40
# 2     VZ       2.0         45.0750          38.89   90.1500 -0.040001  39.05
# 3   JEPI       6.0         56.8266          56.06  340.9596  0.370003  56.06
# 4   JEPI       3.0         59.0966          56.06  177.2898  0.370003  56.06
#
#       High    Low    Volume  Trade Date          Industry
# 0  55.7409  54.86   5837385    20240108              REIT
# 1  55.7409  54.86   5837385    20240125              REIT
# 2  39.1900  38.75  12837931    20230202  Telecom Services
# 3  56.1100  55.82   3605489    20221114               ETF
# 4  56.1100  55.82   3605489    20221222               ETF

# %%
print(df)
# Out:
#        Symbol  Quantity  Purchase Price  Current Price        Cost    Change  \
# 0           O     3.000         58.8900          55.26  176.670000  0.349998
# 1           O    13.000         55.4800          55.26  721.240000  0.349998
# 2          VZ     2.000         45.0750          38.89   90.150000 -0.040001
# 3        JEPI     6.000         56.8266          56.06  340.959600  0.370003
# 4        JEPI     3.000         59.0966          56.06  177.289800  0.370003
# 5      XEI.TO    10.000         27.9530          25.04  279.530000  0.160002
# 6      ZDV.TO     8.000         20.0400          20.02  160.320000  0.150000
# 7      BCE.TO     6.000         61.3783          45.96  368.269800  0.820000
# 8      BCE.TO     2.000         65.4750          45.96  130.950000  0.820000
# 9        SCHD     5.000         76.8500          77.97  384.250000  0.700005
# 10       SCHD     3.000         78.5860          77.97  235.758000  0.700005
# ...

# %%
df['Growth']= (df['Current Price'] - df['Purchase Price'])/df['Purchase Price']
df1=df.groupby(by= ['Symbol']).mean
print(df1)
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000023548B39A90>>
